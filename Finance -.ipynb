# %%
from yahoo_finance import Share

# %%
yahoo = Share('YHOO')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/yahoo_finance/__init__.py in _request(self, query)
#     119         try:
# --> 120             _, results = response['query']['results'].popitem()
#     121         except (KeyError, StopIteration, AttributeError):
#
# AttributeError: 'NoneType' object has no attribute 'popitem'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/yahoo_finance/__init__.py in _request(self, query)
#     122             try:
# --> 123                 raise YQLQueryError(response['error']['description'])
#     124             except KeyError:
#
# KeyError: 'error'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
from pandas_datareader import data as pdr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-bdefcce63d15> in <module>()
# ----> 1 from pandas_datareader import data as pdr
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
import webhoseio

webhoseio.config(token="cab5bada-390e-49db-a074-875e733b45bc")
query_params = {
"q": "TCS stocks",
"ts": "1538552337380",
"sort": "published"
}
output = webhoseio.query("filterWebContent", query_params)
print (output['posts'][10]) # Print the text of the first post
print("-------")
#print (output['posts'][0]['text']) # Print the text of the first post publication date
print("-------")
#print(output)

# Get the next batch of posts

#output = webhoseio.get_next()


# Print the site of the first post

#print (output['posts'][10]['thread']['site'])
# Out:
# {'thread': {'uuid': 'defcea7fd196437e63aa15b559ee468b871c1b11', 'url': 'http://omgili.com/ri/.wHSUbtEfZRiQ2F6hWlN6RtIlHYh_uax759d37fwUX1_4dK_XfGIzYl83ndiPG8omuLPK2yInIhZhyTp61WPpTS4tPqrMBmDFcVAAQJA8qs-', 'site_full': 'www.bullfax.com', 'site': 'bullfax.com', 'site_section': 'https://www.bullfax.com/', 'site_categories': [], 'section_title': 'Market News and Analysis - Leading Stories | www.bullfax.com', 'title': 'Sensex crashes 600 points: Factors behind this mayhem', 'title_full': 'Sensex crashes 600 points: Factors behind this mayhem | www.bullfax.com', 'published': '2018-10-04T08:41:00.000+03:00', 'replies_count': 0, 'participants_count': 1, 'site_type': 'news', 'country': 'US', 'spam_score': 0.0, 'main_image': '', 'performance_score': 0, 'domain_rank': None, 'social': {'facebook': {'likes': 0, 'comments': 0, 'shares': 0}, 'gplus': {'shares': 0}, 'pinterest': {'shares': 0}, 'linkedin': {'shares': 0}, 'stumbledupon': {'shares': 0}, 'vk': {'shares': 0}}}, 'uuid': 'defcea7fd196437e63
# ...

# %%
output['posts'][0]
# Out:
# {'thread': {'uuid': 'bcf457b37cfd92af6035068cf99e138f8dd9f09e',
#   'url': 'http://omgili.com/ri/.wHSUbtEfZQhH3h8jj7Vt0TTVIW0.4gW8NlqbLUr5lIWAiIXLkHlCEk80IK8z5HOB6ukyqrxy5Hc6__D1NdfBGZscn5Cx1xiPupNHs9Z7ZoBvBbrrxymDtGbYtZCCSMFGUmamLUvs1rmN0NW8KDOG3jrokzYTskxdqxWuSCfB9m6Gi.rPbYtcWRgXA1MInWMqxOk5c92rXkdB_uqfOWop_b0T7Xo1XZdAIaXyQJqZeFxaBhP3y2Ja.0_2PULwdrdRRndTqAq0dqqVXfQq0nOmEV4YHSnOBT0aWegFdo8hdo-',
#   'site_full': 'www.financialexpress.com',
#   'site': 'financialexpress.com',
#   'site_section': 'https://www.financialexpress.com/',
#   'site_categories': ['media'],
#   'section_title': 'Business News, India Stock Market, Personal Finance, IPO, Financial News Headlines - The Financial Express',
#   'title': 'Share market LIVE updates: Sensex down 800 pts, Nifty tests 10,600; rupee at record low; RIL down 6%',
#   'title_full': 'Share market LIVE updates: Sensex down 800 pts, Nifty tests 10,600; rupee at record low; RIL down 6% - The Financial Express',
# ...

# %%
for i in range (0,len(output['posts'])):
    print(output['posts'][i]['thread']['site_full'])
    print(output['posts'][i]['thread']['title'])
    print(output['posts'][i]['text'])
    
    #alphabet = output['posts'][i]['text']
    #data = alphabet.split("\n") #split string into a list

    #for temp in data:
    #print (temp)
    print("---------------------------------------")
# Out:
# www.financialexpress.com
# Share market LIVE updates: Sensex down 800 pts, Nifty tests 10,600; rupee at record low; RIL down 6%
# Share market LIVE: All the sectoral indices on the NSE slipped into the negative territory. Share market LIVE: The BSE Sensex extended losses during late-morning trade deals on Thursday and plunged 812 points to an intra-day low of 35,163.28 points. The Nifty tested the 10,600-level and hit a low of 10,605.45 points on huge sell-off across all sectors. Mukesh Ambani -led Reliance Industries slumped 6% and was the top drag on both the Sensex and Nifty indices.
# All the sectoral indices on the NSE slipped into the negative territory led by IT, FMCG, realty, financial services, and auto. Reliance Industries, HDFC twins, TCS, ICICI Bank, Infosys, HUL and Kotak Bank were the top drags on the Sensex in early morning trade deals on Thursday.
# ...

# %%
wordCloud(text)

keyword = input("Enter the keyword: ")
fileName = input("saved file name: ")

search = x.textMining(keyword,fileName)
search = search.drop(['index'], axis =1)
search

#creating html tabs
count = ""
outcome_html = ""

for index, row in search.iterrows():
    #print("<tr>"+ count +"<td>"+str(row['FLIGHT_NUMBER'])+"</td><td>"+str(row['ORIGIN_AIRPORT'])+"</td><td>"+str(row['DEST_AIRPORT'])+"</td><td>"+str(row['OVERALL_SATISFACTION_SCORE'])+"</td><td>"+str(row['NET_PROMOTER_SCORE'])+"</td><td>"+str(row['COMMENTS'])+"</td><td>"+str(row['SENTIMENT_VALUE'])+ "</td></tr>\n")
    outcome_html = outcome_html+"<tr>"+ count +"<td>"+str(row['FLIGHT_NUMBER'])+"</td><td>"+str(row['ORIGIN_AIRPORT'])+"</td><td>"+str(row['DEST_AIRPORT'])+"</td><td>"+str(row['OVERALL_SATISFACTION_SCORE'])+"</td><td>"+str(row['NET_PROMOTER_SCORE'])+"</td><td>"+str(row['COMMENTS'])+"</td><td>"+str(row['SENTIMENT_VALUE'])+ "</td></tr>\n"

#f = open('output.txt', encoding='utf-8', mode='w')
#f.write(outcome_html)
#f.close()

# %%
import webbrowser

f = open('/Users/united/Desktop/Britto/output/testOutput.html','w')

message = """<!DOCTYPE html>
<html>
<head>
<style>
#customers {
    font-family: "Trebuchet MS", Arial, Helvetica, sans-serif;
    border-collapse: collapse;
    width: 100%;
}

#customers td, #customers th {
    padding: 8px;
}

#customers tr:nth-child(even){background-color: #f2f2f2;}

#customers tr:hover {background-color: #ddd;}

#customers th {
    padding-top: 12px;
    padding-bottom: 12px;
    text-align: center;
    background-color: #4CAF50;
    color: white;
}
#customers p:hover {background-color: #ddd;}

</style>
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="https://www.w3schools.com/w3css/4/w3.css">
</head>
<body>
<div class="w3-container">
<table id="customers" class="w3-table w3-striped w3-border">
<tr>
    <th>FLIGHT NUMBER</th>
    <th>ORIGIN AIRPORT</th>
    <th>DEST AIRPORT</th>
</tr>"""+output+"""</table></div></body></html>"""

f.write(message)
f.close()

#Change path to reflect file location
filename = 'file:///Users/united/Desktop/Britto/output/'+'testOutput.html'
webbrowser.open_new_tab(filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-465b8409052c> in <module>()
#      41     <th>ORIGIN AIRPORT</th>
#      42     <th>DEST AIRPORT</th>
# ---> 43 </tr>"""+output+"""</table></div></body></html>"""
#      44
#      45 f.write(message)
#
# TypeError: must be str, not dict

# %%
GET
https://newsapi.org/v2/top-headlines?sources=google-news-in&apiKey=2616a0f0217e42be939043f72497ffa1
# Out:
#   File "<ipython-input-53-cee47045f02d>", line 2
#     https://newsapi.org/v2/top-headlines?sources=google-news-in&apiKey=2616a0f0217e42be939043f72497ffa1
#            ^
# SyntaxError: invalid syntax
